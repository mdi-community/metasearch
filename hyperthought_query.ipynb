# %%
import requests
import json
search_term="test"
url="https://www.icemaker.afrlmakerhub.com/api/accio/marklogic_search/?rs%3Aq={}&rs%3AgraphUri=http%3A%2F%2Fmarklogic.icemaker.afrlmakerhub.com%3A8016%2Fv1%2Fgraphs%2Fmbo".format(search_term)
response = requests.get(url)
response.json()
# Out:
# {'end': 25,
#  'facets': {'Creator': {'facets': {'schwalej': 5,
#     'BreedoA': 1,
#     'fourmajr': 3,
#     'jacobsmd': '1',
#     'PhilliGK': 1,
#     'LatimeJJ': 1,
#     'PhilliGK3': 8,
#     'HerveyWJ': 1},
#    'label': 'created_by'},
#   'File Type': {'facets': {'': 1,
#     'ino': 1,
#     'txt': 3,
#     'm2ts': 1,
#     'stl': 1,
#     'Folder': 8,
#     'SLDPRT': 6,
#     'xlsx': 9,
#     'Igs': 1,
#     'rpt': 2,
#     'STL': 4,
#     'xls': 1,
#     'TXT': 1,
#     'csv': 3,
#     'xml': 1,
#     'png': 1,
#     'docx': 5},
#    'label': 'ftype'},
#   'Modified On': {'facets': {'2018-07': 1,
#     '2018-10': '1',
#     '2018-08': 1,
#     '2018-12': 1,
#     '2018-11': 1,
#     '2018-04': 1,
#     '2018-03': 1,
#     '2018-09': 1,
#     '2019-02': 1,
#     '2019-01': 1,
#     '2019-03': 1,
#     '2019-04': 1,
#     '2018-05': 1},
#    'label': 'modified'},
#   'Object Type': {'facets': {'workflow': 22, 'Data Model': '1', 'process': 7},
#    'label': 'process_type'},
# ...
